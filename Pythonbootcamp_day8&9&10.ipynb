# %% [markdown]
# <a href="https://colab.research.google.com/github/fatimashaista/Python/blob/main/Pythonbootcamp_day8%269%2610.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Working with Files

# %%
f=open("welcome.txt", "r")
print(f.read())
f.close()
# Out:
# Hello all
# welcome to python bootcamp
# you are great

# %%
f=open("welcome.txt", "r")
print(f.read(5))
f.close()
# Out:
# Hello

# %%
f=open("welcome.txt", "r")
print(f.readline())
f.close()
# Out:
# Hello all

# %%
f=open("welcome.txt", "r")
print(f.readlines())
f.close()
# Out:
# ['Hello all\n', 'welcome to python bootcamp\n', 'you are great']

# %%
f=open("welcome.txt", "r")
for x in f:
  print(x)
# Out:
# Hello all
#
# welcome to python bootcamp
#
# you are great

# %% [markdown]
# ###File handling using pandas

# %%
# !pip install pandas

# %%
import pandas as pd
data=pd.read_csv('data.csv')
print(data.to_string())
# Out:
#     Unnamed: 0  Age  salary  status
# 0            0   18   82000       0
# 1            1   29   80000       0
# 2            2   47   25000       1
# 3            3   45   26000       1
# 4            4   46   28000       1
# 5            5   48   29000       1
# 6            6   45   22000       1
# 7            7   47   49000       1
# 8            8   48   41000       1
# 9            9   45   22000       1
# 10          10   46   23000       1
# 11          11   47   20000       1
# 12          12   49   28000       1
# 13          13   47   30000       1

# %%
import pandas as pd
data=pd.read_csv('data.csv')
print(data.shape)
print(data.describe())
print(data.head(5))
# Out:
# (14, 4)
#        Unnamed: 0        Age        salary     status
# count     14.0000  14.000000     14.000000  14.000000
# mean       6.5000  43.357143  36071.428571   0.857143
# std        4.1833   8.767134  20563.089732   0.363137
# min        0.0000  18.000000  20000.000000   0.000000
# 25%        3.2500  45.000000  23500.000000   1.000000
# 50%        6.5000  46.500000  28000.000000   1.000000
# 75%        9.7500  47.000000  38250.000000   1.000000
# max       13.0000  49.000000  82000.000000   1.000000
#    Unnamed: 0  Age  salary  status
# 0           0   18   82000       0
# 1           1   29   80000       0
# 2           2   47   25000       1
# 3           3   45   26000       1
# 4           4   46   28000       1

# %% [markdown]
# ###Working with Directories

# %%
import os
print(os.getcwd()) #current working directory
print(os.listdir())
os.mkdir("junk")
# Out:
# /content
# ['.config', 'sample_data']

# %% [markdown]
# ###To move a file into the folder

# %%
import shutil
shutil.move('welcome.txt','/content/junk')
# Out:
# '/content/junk/welcome.txt'

# %%
os.listdir()
# Out:
# ['.config', '.ipynb_checkpoints', 'junk', 'sample_data']

# %% [markdown]
# ### Deleting any file

# %%
import send2trash
os.listdir()
send2trash.send2trash('junk/welcome.txt')

# %%
os.listdir()
# Out:
# ['.config', '.ipynb_checkpoints', 'junk', 'sample_data']

# %% [markdown]
# ###Time

# %%
import time
startTime=time.time()
i=0
while(i<5):
  i+=1
  print(".")
  time.sleep(1)
stopTime=time.time()
diff = stopTime-startTime
diff
# Out:
# .
# .
# .
# .
# .
# 5.008936405181885

# %% [markdown]
# ###Date &Time

# %%
import datetime
x = datetime.datetime.now()
print(x)
# Out:
# 2022-03-13 19:37:54.088907

# %% [markdown]
# ###To set date & time

# %%
import datetime
x = datetime.datetime(2021,  12, 16, 12, 30, 51) #(year,month,date,hour,minutes,second,micro)
print(x)
# Out:
# 2021-12-16 12:30:51

# %%
import datetime
a = datetime.datetime(2021,  12, 16) #(year,month,date,hour,minutes,second,micro)
print(a.strftime("%B"))
# Out:
# December

# %%
import datetime
a = datetime.datetime(2021,  12, 16) #(year,month,date,hour,minutes,second,micro)
print(a.strftime("%a"))
# Out:
# Thu

# %% [markdown]
# #DAY 9

# %% [markdown]
# ##Web Scraping

# %%
# !pip install requests
# !pip install bs4
# !pip install html
# !pip install lxml

# %% [markdown]
# ###urlib request Library

# %%
import urllib.request #Handling URL
from bs4 import BeautifulSoup #Handling or parsing html files
response = urllib.request.urlopen("https://en.wikipedia.org/wiki/Nikola_Tesla")
htmlFormat=response.read()
htmlFormat
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Nikola Tesla - Wikipedia</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"b7d73593-4e25-4744-8498-251ce649befc","wgCSPNonce":false,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Nikola_Tesla","wgTitle":"Nikola Tesla","wgCurRevisionId":1076402542,"wgRevisionId":1076402542,"wgArticleId":21473,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Harv and Sfn no-target errors","CS1: Julian\xe2\x80\x93Gregorian uncertainty","All articles lacking reliable references","Articles lacking reliable r
# ...

# %%
# !pip install BeautifulSoup
# Out:
# ...
# WARNING: Discarding https://files.pythonhosted.org/packages/40/f2/6c9f2f3e696ee6a1fb0e4d7850617e224ed2b0b1e872110abffeca2a09d4/BeautifulSoup-3.2.2.tar.gz#sha256=a04169602bff6e3138b1259dbbf491f5a27f9499dea9a8fbafd48843f9d89970 (from https://pypi.org/simple/beautifulsoup/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
# ...
# WARNING: Discarding https://files.pythonhosted.org/packages/1e/ee/295988deca1a5a7accd783d0dfe14524867e31abb05b6c0eeceee49c759d/BeautifulSoup-3.2.1.tar.gz#sha256=6a8cb4401111e011b579c8c52a51cdab970041cc543814bbd9577a4529fe1cdb (from https://pypi.org/simple/beautifulsoup/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
# ...

# %%
soup = BeautifulSoup(htmlFormat,'html5lib')
text=soup.get_text(strip=True)
tokens = [t for t in text.split( )]
tokens
